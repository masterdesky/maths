# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %%
N = 128
X = np.ones((N,N))

# 1. Drop some columns uniformly
X[:,1::16] = 0
X[:,2::16] = 0
#X[:,3::16] = 0

# 2. Select some random centers and values to start "spreading"
C = tuple(tuple(np.random.randint(0, N) for i in range(2)) for i in range(7))
V = [np.random.random() for i in range(7)]
X[tuple(zip(*C))] = V

# 3. 
def fill_step(C, p=0.85):
  
  for c in C:
    
  
  return X_

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.axis('off')

ax.imshow(X,
          cmap=cm.brg, interpolation='none')

plt.show()
